# %%
import os
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 300)
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import sys
sys.path.append(os.path.abspath('../'))

import warnings
warnings.filterwarnings("ignore")

from server2022.src.train_val import *
from server2022.src.model_features import *
from server2022.data.processed.prepare_data import *


OUTPUT_FILE = '../reports/0_30_90_comp.csv'

TARGET_DICT = {'1': 'binary_target', '2': 'target_more30days', '3': 'target_more90days'}
'''Choose target: 
    1 - binary_target
    2 - target_more30days
    3 - target_more90days
'''
# Out:
# 'Choose target: \n    1 - binary_target\n    2 - target_more30days\n    3 - target_more90days\n'

# %%
TARGET_COL = TARGET_DICT['1']
COMMENT_PREFIX = '0'

# %%
model = CatBoostClassifier(iterations=1500,
                               depth=5, 
                               l2_leaf_reg=5, 
                               learning_rate=0.001, # 0.01433
                               loss_function='Logloss',
                               use_best_model=False,
                               eval_metric='AUC',
                               verbose=False,
                               class_weights=[1, 0.01], #0.0006
                               random_seed=RANDOM_STATE,
                              )

# %% [markdown]
# ## add_growth=True + use_diff_features=True

# %%
df = create_df_1year_known(add_growth=True, count_log_fin_vals=False, normalize_fin_columns=False, drop_zeros=False)

# %%
feat_gen = Feature_gen(-2, -1)
df = feat_gen.preprocessing_before_fitting(df, use_diff_features=True, use_ratio_features=False)

# %%
make_report_with_best_threshold(model, df, to_file=True, target_col=TARGET_COL, num_random_states=5,
                                file_path=OUTPUT_FILE, comment=COMMENT_PREFIX + '2 + 4')
# Out:
# Target = binary_target
# Fitting model <catboost.core.CatBoostClassifier object at 0x000002299D584880> with threshold = 0.06...
# TRAIN: F1 = 0.615, Precision = 0.857, Recall = 0.479, Accuracy = 0.589, ROC_AUC = 0.752
# TEST: F1 = 0.662, Precision = 0.53, Recall = 0.883, Accuracy = 0.692, ROC_AUC = 0.746

# %% [markdown]
# ## add_growth=True + use_diff_features=True + normalize_fin_columns=True

# %%
df = create_df_1year_known(add_growth=True, count_log_fin_vals=False, normalize_fin_columns=True, drop_zeros=False)

# %%
feat_gen = Feature_gen(-2, -1)
df = feat_gen.preprocessing_before_fitting(df, use_diff_features=True, use_ratio_features=False)

# %%
make_report_with_best_threshold(model, df, to_file=True, target_col=TARGET_COL, num_random_states=5,
                                file_path=OUTPUT_FILE, comment=COMMENT_PREFIX + '2 + 4 + 6')
# Out:
# Target = binary_target
# Fitting model <catboost.core.CatBoostClassifier object at 0x000002299D584880> with threshold = 0.05742...
# TRAIN: F1 = 0.626, Precision = 0.824, Recall = 0.504, Accuracy = 0.588, ROC_AUC = 0.734
# TEST: F1 = 0.651, Precision = 0.522, Recall = 0.865, Accuracy = 0.683, ROC_AUC = 0.738

# %% [markdown]
# ## add_growth=True + use_diff_features=True + normalize_fin_columns=True + count_log_fin_vals=True

# %%
df = create_df_1year_known(add_growth=True, count_log_fin_vals=True, normalize_fin_columns=True, drop_zeros=False)

# %%
feat_gen = Feature_gen(-2, -1)
df = feat_gen.preprocessing_before_fitting(df, use_diff_features=True, use_ratio_features=False)

# %%
make_report_with_best_threshold(model, df, to_file=True, target_col=TARGET_COL, num_random_states=5,
                                file_path=OUTPUT_FILE, comment=COMMENT_PREFIX + '2 + 4 + 5 + 6')
# Out:
# Target = binary_target
# Fitting model <catboost.core.CatBoostClassifier object at 0x000002299D584880> with threshold = 0.05727...
# TRAIN: F1 = 0.633, Precision = 0.858, Recall = 0.501, Accuracy = 0.603, ROC_AUC = 0.757
# TEST: F1 = 0.634, Precision = 0.5, Recall = 0.865, Accuracy = 0.658, ROC_AUC = 0.731

# %% [markdown]
# ## add_growth=True + use_diff_features=True + normalize_fin_columns=True + count_log_fin_vals=True + use_ratio_features=True

# %%
df = create_df_1year_known(add_growth=True, count_log_fin_vals=True, normalize_fin_columns=True, drop_zeros=False)

# %%
feat_gen = Feature_gen(-2, -1)
df = feat_gen.preprocessing_before_fitting(df, use_diff_features=True, use_ratio_features=True)

# %%
make_report_with_best_threshold(model, df, to_file=True, target_col=TARGET_COL, num_random_states=5,
                                file_path=OUTPUT_FILE, comment=COMMENT_PREFIX + '2 + 3 + 4 + 5 + 6')
# Out:
# Target = binary_target
# Fitting model <catboost.core.CatBoostClassifier object at 0x000002299D584880> with threshold = 0.0589...
# TRAIN: F1 = 0.617, Precision = 0.866, Recall = 0.479, Accuracy = 0.593, ROC_AUC = 0.76
# TEST: F1 = 0.655, Precision = 0.527, Recall = 0.865, Accuracy = 0.689, ROC_AUC = 0.731

# %%
TARGET_COL = TARGET_DICT['2']
COMMENT_PREFIX = '30'

# %%
model = CatBoostClassifier(iterations=1500,
                               depth=4, 
                               l2_leaf_reg=8.8, 
                               learning_rate=0.0192, # 0.01433
                               loss_function='Logloss',
                               use_best_model=False,
                               eval_metric='AUC',
                               verbose=False,
                               class_weights=[1, 0.1], #0.0006
                               random_seed=RANDOM_STATE,
                              )

# %% [markdown]
# ## add_growth=True + use_diff_features=True

# %%
df = create_df_1year_known(add_growth=True, count_log_fin_vals=False, normalize_fin_columns=False, drop_zeros=False)

# %%
feat_gen = Feature_gen(-2, -1)
df = feat_gen.preprocessing_before_fitting(df, use_diff_features=True, use_ratio_features=False)

# %%
make_report_with_best_threshold(model, df, to_file=True, target_col=TARGET_COL, num_random_states=5,
                                file_path=OUTPUT_FILE, comment=COMMENT_PREFIX + '2 + 4')
# Out:
# Target = target_more30days
# Fitting model <catboost.core.CatBoostClassifier object at 0x000002299EAAC940> with threshold = 0.01435...
# TRAIN: F1 = 0.509, Precision = 0.367, Recall = 0.831, Accuracy = 0.75, ROC_AUC = 0.877
# TEST: F1 = 0.575, Precision = 0.429, Recall = 0.87, Accuracy = 0.695, ROC_AUC = 0.837

# %% [markdown]
# ## add_growth=True + use_diff_features=True + normalize_fin_columns=True

# %%
df = create_df_1year_known(add_growth=True, count_log_fin_vals=False, normalize_fin_columns=True, drop_zeros=False)

# %%
feat_gen = Feature_gen(-2, -1)
df = feat_gen.preprocessing_before_fitting(df, use_diff_features=True, use_ratio_features=False)

# %%
make_report_with_best_threshold(model, df, to_file=True, target_col=TARGET_COL, num_random_states=5,
                                file_path=OUTPUT_FILE, comment=COMMENT_PREFIX + '2 + 4 + 6')
# Out:
# Target = target_more30days
# Fitting model <catboost.core.CatBoostClassifier object at 0x000002299EAAC940> with threshold = 0.01382...
# TRAIN: F1 = 0.462, Precision = 0.325, Recall = 0.795, Accuracy = 0.71, ROC_AUC = 0.848
# TEST: F1 = 0.576, Precision = 0.428, Recall = 0.883, Accuracy = 0.692, ROC_AUC = 0.833

# %% [markdown]
# ## add_growth=True + use_diff_features=True + normalize_fin_columns=True + count_log_fin_vals=True

# %%
df = create_df_1year_known(add_growth=True, count_log_fin_vals=True, normalize_fin_columns=True, drop_zeros=False)

# %%
feat_gen = Feature_gen(-2, -1)
df = feat_gen.preprocessing_before_fitting(df, use_diff_features=True, use_ratio_features=False)

# %%
make_report_with_best_threshold(model, df, to_file=True, target_col=TARGET_COL, num_random_states=5,
                                file_path=OUTPUT_FILE, comment=COMMENT_PREFIX + '2 + 4 + 5 + 6')
# Out:
# Target = target_more30days
# Fitting model <catboost.core.CatBoostClassifier object at 0x000002299EAAC940> with threshold = 0.01348...
# TRAIN: F1 = 0.481, Precision = 0.34, Recall = 0.819, Accuracy = 0.723, ROC_AUC = 0.864
# TEST: F1 = 0.571, Precision = 0.422, Recall = 0.883, Accuracy = 0.686, ROC_AUC = 0.825

# %% [markdown]
# ## add_growth=True + use_diff_features=True + normalize_fin_columns=True + count_log_fin_vals=True + use_ratio_features=True

# %%
df = create_df_1year_known(add_growth=True, count_log_fin_vals=True, normalize_fin_columns=True, drop_zeros=False)

# %%
feat_gen = Feature_gen(-2, -1)
df = feat_gen.preprocessing_before_fitting(df, use_diff_features=True, use_ratio_features=True)

# %%
make_report_with_best_threshold(model, df, to_file=True, target_col=TARGET_COL, num_random_states=5,
                                file_path=OUTPUT_FILE, comment=COMMENT_PREFIX + '2 + 3 + 4 + 5 + 6')
# Out:
# Target = target_more30days
# Fitting model <catboost.core.CatBoostClassifier object at 0x000002299EAAC940> with threshold = 0.01376...
# TRAIN: F1 = 0.474, Precision = 0.332, Recall = 0.831, Accuracy = 0.712, ROC_AUC = 0.881
# TEST: F1 = 0.541, Precision = 0.388, Recall = 0.896, Accuracy = 0.64, ROC_AUC = 0.82

# %%
TARGET_COL = TARGET_DICT['3']
COMMENT_PREFIX = '90'

# %%
model = CatBoostClassifier(iterations=1500,
                               depth=4, 
                               l2_leaf_reg=8.8, 
                               learning_rate=0.0192, # 0.01433
                               loss_function='Logloss',
                               use_best_model=False,
                               eval_metric='AUC',
                               verbose=False,
                               class_weights=[1, 0.1], #0.0006
                               random_seed=RANDOM_STATE,
                              )

# %% [markdown]
# ## add_growth=True + use_diff_features=True

# %%
df = create_df_1year_known(add_growth=True, count_log_fin_vals=False, normalize_fin_columns=False, drop_zeros=False)

# %%
feat_gen = Feature_gen(-2, -1)
df = feat_gen.preprocessing_before_fitting(df, use_diff_features=True, use_ratio_features=False)

# %%
make_report_with_best_threshold(model, df, to_file=True, target_col=TARGET_COL, num_random_states=5,
                                file_path=OUTPUT_FILE, comment=COMMENT_PREFIX + '2 + 4')
# Out:
# Target = target_more90days
# Fitting model <catboost.core.CatBoostClassifier object at 0x000002299ECF4B20> with threshold = 0.00406...
# TRAIN: F1 = 0.215, Precision = 0.123, Recall = 0.848, Accuracy = 0.616, ROC_AUC = 0.817
# TEST: F1 = 0.555, Precision = 0.394, Recall = 0.94, Accuracy = 0.689, ROC_AUC = 0.912

# %% [markdown]
# ## add_growth=True + use_diff_features=True + normalize_fin_columns=True

# %%
df = create_df_1year_known(add_growth=True, count_log_fin_vals=False, normalize_fin_columns=True, drop_zeros=False)

# %%
feat_gen = Feature_gen(-2, -1)
df = feat_gen.preprocessing_before_fitting(df, use_diff_features=True, use_ratio_features=False)

# %%
make_report_with_best_threshold(model, df, to_file=True, target_col=TARGET_COL, num_random_states=5,
                                file_path=OUTPUT_FILE, comment=COMMENT_PREFIX + '2 + 4 + 6')
# Out:
# Target = target_more90days
# Fitting model <catboost.core.CatBoostClassifier object at 0x000002299ECF4B20> with threshold = 0.00466...
# TRAIN: F1 = 0.229, Precision = 0.136, Recall = 0.727, Accuracy = 0.695, ROC_AUC = 0.777
# TEST: F1 = 0.636, Precision = 0.481, Recall = 0.94, Accuracy = 0.778, ROC_AUC = 0.938

# %% [markdown]
# ## add_growth=True + use_diff_features=True + normalize_fin_columns=True + count_log_fin_vals=True

# %%
df = create_df_1year_known(add_growth=True, count_log_fin_vals=True, normalize_fin_columns=True, drop_zeros=False)

# %%
feat_gen = Feature_gen(-2, -1)
df = feat_gen.preprocessing_before_fitting(df, use_diff_features=True, use_ratio_features=False)

# %%
make_report_with_best_threshold(model, df, to_file=True, target_col=TARGET_COL, num_random_states=5,
                                file_path=OUTPUT_FILE, comment=COMMENT_PREFIX + '2 + 4 + 5 + 6')
# Out:
# Target = target_more90days
# Fitting model <catboost.core.CatBoostClassifier object at 0x000002299ECF4B20> with threshold = 0.00411...
# TRAIN: F1 = 0.223, Precision = 0.131, Recall = 0.758, Accuracy = 0.672, ROC_AUC = 0.83
# TEST: F1 = 0.589, Precision = 0.436, Recall = 0.91, Accuracy = 0.738, ROC_AUC = 0.923

# %% [markdown]
# ## add_growth=True + use_diff_features=True + normalize_fin_columns=True + count_log_fin_vals=True + use_ratio_features=True

# %%
df = create_df_1year_known(add_growth=True, count_log_fin_vals=True, normalize_fin_columns=True, drop_zeros=False)

# %%
feat_gen = Feature_gen(-2, -1)
df = feat_gen.preprocessing_before_fitting(df, use_diff_features=True, use_ratio_features=True)

# %%
make_report_with_best_threshold(model, df, to_file=True, target_col=TARGET_COL, num_random_states=5,
                                file_path=OUTPUT_FILE, comment=COMMENT_PREFIX + '2 + 3 + 4 + 5 + 6')
# Out:
# Target = target_more90days
# Fitting model <catboost.core.CatBoostClassifier object at 0x000002299ECF4B20> with threshold = 0.004...
# TRAIN: F1 = 0.227, Precision = 0.131, Recall = 0.848, Accuracy = 0.64, ROC_AUC = 0.877
# TEST: F1 = 0.575, Precision = 0.421, Recall = 0.91, Accuracy = 0.723, ROC_AUC = 0.9
