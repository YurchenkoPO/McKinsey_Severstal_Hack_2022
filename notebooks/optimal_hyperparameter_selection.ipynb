# %%
import os
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 200)
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import sys
sys.path.append(os.path.abspath('../'))
from hyperopt import hp
from hyperopt import fmin, tpe, STATUS_OK, STATUS_FAIL, Trials
import warnings
warnings.filterwarnings("ignore")

from server2022.src.train_val import *
from server2022.src.model_features import *
from server2022.data.processed.prepare_data import *

# %%
# df = create_df_0years_known(count_log_fin_vals=False)
df = create_df_1year_known(count_log_fin_vals=False)

# %%
feat_gen = Feature_gen(-4, -1)
df = feat_gen.preprocessing_before_fitting(df)
df = df.loc[:, [col for col in df.columns if 'Факт' not in col and 'руб' not in col]]

# %%
df.head(3)
# Out:
#    Наименование ДП  Итого  year  binary_target  Макс. ПДЗ за -1 год, дней  \
# 0                0   10.0  2020           True                          0
# 1                1   20.0  2020           True                          0
# 2                2   40.0  2020           True                          7
#
#    Сред. ПДЗ за -1 год, дней  Кол-во просрочек свыше 5-ти дней за -1 год, шт.  \
# 0                        0.0                                                0
# 1                        0.0                                                0
# 2                        5.5                                                1
#
#    Кол-во раз ПДЗ за -1 год, шт.  \
# 0                              0
# 1                              0
# 2                              2
#
#    Нематериальные активы, относительный прирост за -3 год  \
# 0                                           1.157061
# 1                                          -0.131451
# ...

# %%
best = hyperopt_for_catboost(df)
# Out:
#
# CatBoost objective call #1 cur_best_score=0.00000
# Params: depth=7.0 learning_rate=0.0037374878397794043
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000020C628E49A0> with treshold = 0.5...
# nb_trees=2000
# NEW BEST LOSS=11.796340235737008
# NEW BEST ROC_AUC=0.6451545002946872
#
# CatBoost objective call #2 cur_best_score=0.64515
# Params: depth=7.0 learning_rate=0.003916380696136947
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000020C628E43D0> with treshold = 0.5...
# nb_trees=2000
# NEW BEST LOSS=11.796337775437221
# NEW BEST ROC_AUC=0.6436389660688726
#
# CatBoost objective call #3 cur_best_score=0.64364
# Params: depth=8.0 learning_rate=0.005523750665355358
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000020C628FCF70> with treshold = 0.5...
# nb_trees=2000
#
# CatBoost objective call #4 cur_best_score=0.64364
# Params: depth=7.0 learning_rate=0.052434422076869214
# ...
