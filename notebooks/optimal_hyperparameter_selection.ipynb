# %%
import os
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 200)
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import sys
sys.path.append(os.path.abspath('../'))
from hyperopt import hp
from hyperopt import fmin, tpe, STATUS_OK, STATUS_FAIL, Trials
import warnings
warnings.filterwarnings("ignore")

from server2022.src.train_val import *
from server2022.src.model_features import *
from server2022.data.processed.prepare_data import *

# %%
# df = create_df_0years_known()
df = create_df_1year_known()

# %%
feat_gen = Feature_gen(-4, -1)
df = feat_gen.preprocessing_before_fitting(df)
df = df.loc[:, [col for col in df.columns if 'Факт' not in col]]

# %%
df.head(3)
# Out:
#    Наименование ДП  Итого  year  binary_target  Макс. ПДЗ за -1 год, дней  \
# 0                0   10.0  2020           True                          0
# 1                1   20.0  2020           True                          0
# 2                2   40.0  2020           True                          7
#
#    Сред. ПДЗ за -1 год, дней  Кол-во просрочек свыше 5-ти дней за -1 год, шт.  \
# 0                        0.0                                                0
# 1                        0.0                                                0
# 2                        5.5                                                1
#
#    Общая сумма ПДЗ свыше 5-ти дней за -1 год, руб.  \
# 0                                         0.000000
# 1                                         0.000000
# 2                                    132825.299363
#
#    Кол-во раз ПДЗ за -1 год, шт.  -4, Нематериальные активы, RUB  \
# 0                              0                        0.000413
# 1                              0                        0.000000
# 2                              2                        0.000352
#
#    -3, Нематериальные активы, RUB  -2, Нематериальные активы, RUB  \
# 0                        0.000758                        0.000905
# 1                        0.000005                        0.000003
# 2                        0.001564                        0.000870
#
#    -1, Нематериальные активы, RUB  -4, Основные средства , RUB  \
# 0                        0.000890                     0.002129
# 1                        0.000003                     0.000163
# 2                        0.000446                     0.001093
#
#    -3, Основные средства , RUB  -2, Основные средства , RUB  \
# 0                     0.001809                     0.002040
# 1                     0.000149                     0.000145
# 2                     0.000947                     0.000883
#
#    -1, Основные средства , RUB  -4, Внеоборотные активы, RUB  \
# 0                     0.003475                      0.002040
# 1                     0.000167                      0.000154
# 2                     0.000990                      0.001029
#
#    -3, Внеоборотные активы, RUB  -2, Внеоборотные активы, RUB  \
# 0                      0.001749                      0.002146
# 1                      0.000139                      0.000135
# 2                      0.000964                      0.000896
#
#    -1, Внеоборотные активы, RUB  -4, Дебиторская задолженность, RUB  \
# 0                      0.003384                            0.041569
# 1                      0.000158                            0.000648
# 2                      0.001117                            0.003265
#
#    -3, Дебиторская задолженность, RUB  -2, Дебиторская задолженность, RUB  \
# 0                            0.039589                            0.029057
# 1                            0.000503                            0.001307
# 2                            0.002495                            0.001907
#
#    -1, Дебиторская задолженность, RUB  -4, Оборотные активы, RUB  \
# 0                            0.023933                   0.019742
# 1                            0.001127                   0.000570
# 2                            0.001796                   0.004924
#
#    -3, Оборотные активы, RUB  -2, Оборотные активы, RUB  \
# 0                   0.022314                   0.018853
# 1                   0.000719                   0.000904
# 2                   0.005634                   0.004933
#
#    -1, Оборотные активы, RUB  -4, Уставный капитал , RUB  \
# 0                   0.012718                    0.001246
# 1                   0.000954                    0.000003
# 2                   0.002139                    0.000039
#
#    -3, Уставный капитал , RUB  -2, Уставный капитал , RUB  \
# 0                    0.001246                    0.001246
# 1                    0.000003                    0.000003
# 2                    0.000039                    0.000039
#
#    -1, Уставный капитал , RUB  -4, Капитал и резервы, RUB  \
# 0                    0.001190                    0.056414
# 1                    0.000003                    0.053844
# 2                    0.000037                    0.055812
#
#    -3, Капитал и резервы, RUB  -2, Капитал и резервы, RUB  \
# 0                    0.133443                    0.144200
# 1                    0.131006                    0.142543
# 2                    0.132872                    0.144275
#
#    -1, Капитал и резервы, RUB  -4, Заёмные средства (долгосрочные), RUB  \
# 0                    0.157321                                       0.0
# 1                    0.153904                                       0.0
# 2                    0.155029                                       0.0
#
#    -3, Заёмные средства (долгосрочные), RUB  \
# 0                              1.839381e-08
# 1                              1.839381e-08
# 2                              1.839381e-08
#
#    -2, Заёмные средства (долгосрочные), RUB  \
# 0                              1.839381e-08
# 1                              1.839381e-08
# 2                              1.839381e-08
#
#    -1, Заёмные средства (долгосрочные), RUB  \
# 0                                       0.0
# 1                                       0.0
# 2                                       0.0
#
#    -4, Долгосрочные обязательства, RUB  -3, Долгосрочные обязательства, RUB  \
# 0                             0.000248                             0.000238
# 1                             0.000007                             0.000007
# 2                             0.000017                             0.000014
#
#    -2, Долгосрочные обязательства, RUB  -1, Долгосрочные обязательства, RUB  \
# 0                             0.000233                             0.000230
# 1                             0.000005                             0.000005
# 2                             0.000004                             0.000000
#
#    -4, Заёмные средства (краткосрочные), RUB  \
# 0                                   0.000007
# 1                                   0.000115
# 2                                   0.000007
#
#    -3, Заёмные средства (краткосрочные), RUB  \
# 0                                   0.000000
# 1                                   0.000354
# 2                                   0.000000
#
#    -2, Заёмные средства (краткосрочные), RUB  \
# 0                                   0.002830
# 1                                   0.000460
# 2                                   0.000002
#
#    -1, Заёмные средства (краткосрочные), RUB  \
# 0                                   0.000003
# 1                                   0.000578
# 2                                   0.000003
#
#    -4, Кредиторская задолженность, RUB  -3, Кредиторская задолженность, RUB  \
# 0                             0.050860                             0.069880
# 1                             0.000117                             0.000178
# 2                             0.001032                             0.001408
#
#    -2, Кредиторская задолженность, RUB  -1, Кредиторская задолженность, RUB  \
# 0                             0.057093                             0.026788
# 1                             0.000690                             0.000632
# 2                             0.001290                             0.000888
#
#    -4, Краткосрочные обязательства, RUB  -3, Краткосрочные обязательства, RUB  \
# 0                              0.029436                              0.029130
# 1                              0.000135                              0.000370
# 2                              0.000966                              0.001116
#
#    -2, Краткосрочные обязательства, RUB  -1, Краткосрочные обязательства, RUB  \
# 0                              0.030225                              0.015385
# 1                              0.000658                              0.000707
# 2                              0.001154                              0.000931
#
#    -4, Выручка, RUB  -3, Выручка, RUB  -2, Выручка, RUB  -1, Выручка, RUB  \
# 0          0.099054          0.126791          0.072146          0.057833
# 1          0.000949          0.000784          0.001059          0.001295
# 2          0.010347          0.008222          0.005050          0.004924
#
#    -4, Себестоимость продаж, RUB  -3, Себестоимость продаж, RUB  \
# 0                       0.128633                       0.174874
# 1                       0.001227                       0.001078
# 2                       0.012155                       0.011422
#
#    -2, Себестоимость продаж, RUB  -1, Себестоимость продаж, RUB  \
# 0                       0.162866                       0.120174
# 1                       0.001975                       0.002405
# 2                       0.010974                       0.011061
#
#    -4, Прибыль (убыток) до налогообложения , RUB  \
# 0                                       0.257845
# 1                                       0.238350
# 2                                       0.241369
#
#    -3, Прибыль (убыток) до налогообложения , RUB  \
# 0                                       0.501718
# 1                                       0.472213
# 2                                       0.473925
#
#    -2, Прибыль (убыток) до налогообложения , RUB  \
# 0                                       0.282168
# 1                                       0.280673
# 2                                       0.280760
#
#    -1, Прибыль (убыток) до налогообложения , RUB  \
# 0                                       0.360061
# 1                                       0.354360
# 2                                       0.353171
#
#    -4, Прибыль (убыток) от продажи, RUB  -3, Прибыль (убыток) от продажи, RUB  \
# 0                              0.031369                              0.047538
# 1                              0.008134                              0.008063
# 2                              0.010971                              0.009020
#
#    -2, Прибыль (убыток) от продажи, RUB  -1, Прибыль (убыток) от продажи, RUB  \
# 0                              0.081105                              0.043622
# 1                              0.078554                              0.033549
# 2                              0.078105                              0.032942
#
#    log -4, Нематериальные активы, RUB  log -3, Нематериальные активы, RUB  \
# 0                           14.878683                           15.647430
# 1                           12.504056                           10.567579
# 2                           14.718981                           16.371206
#
#    log -2, Нематериальные активы, RUB  log -1, Нематериальные активы, RUB  \
# 0                           16.018381                           16.106629
# 1                           10.445693                           10.285355
# 2                           15.978248                           15.416634
#
#    log -4, Основные средства , RUB  log -3, Основные средства , RUB  \
# 0                        21.359697                        21.313119
# 1                        18.790939                        18.817544
# 2                        20.692607                        20.666078
#
#    log -2, Основные средства , RUB  log -1, Основные средства , RUB  \
# 0                        21.486517                        22.005893
# 1                        18.843610                        18.967911
# 2                        20.649338                        20.750402
#
#    log -4, Внеоборотные активы, RUB  log -3, Внеоборотные активы, RUB  \
# 0                         21.380104                         21.354985
# 1                         18.796912                         18.824803
# 2                         20.696177                         20.759031
#
#    log -2, Внеоборотные активы, RUB  log -1, Внеоборотные активы, RUB  \
# 0                         21.615296                         22.041713
# 1                         18.851764                         18.976080
# 2                         20.741776                         20.933051
#
#    log -4, Дебиторская задолженность, RUB  \
# 0                               21.999680
# 1                               17.838140
# 2                               19.455528
#
#    log -3, Дебиторская задолженность, RUB  \
# 0                               22.027091
# 1                               17.661013
# 2                               19.262709
#
#    log -2, Дебиторская задолженность, RUB  \
# 0                               21.968993
# 1                               18.867593
# 2                               19.245074
#
#    log -1, Дебиторская задолженность, RUB  log -4, Оборотные активы, RUB  \
# 0                               22.029473                      22.364082
# 1                               18.973782                      18.818888
# 2                               19.439641                      20.975515
#
#    log -3, Оборотные активы, RUB  log -2, Оборотные активы, RUB  \
# 0                      22.497765                      22.527851
# 1                      19.062001                      19.490426
# 2                      21.121427                      21.187136
#
#    log -1, Оборотные активы, RUB  log -4, Уставный капитал , RUB  \
# 0                      22.329056                       20.260278
# 1                      19.739347                       14.112544
# 2                      20.546248                       16.793312
#
#    log -3, Уставный капитал , RUB  log -2, Уставный капитал , RUB  \
# 0                       20.260278                       20.260278
# 1                       14.112544                       14.112544
# 2                       16.793312                       16.793312
#
#    log -1, Уставный капитал , RUB  log -4, Капитал и резервы, RUB  \
# 0                       20.260278                       21.706475
# 1                       14.112544                       19.423754
# 2                       16.793312                       21.470155
#
#    log -3, Капитал и резервы, RUB  log -2, Капитал и резервы, RUB  ...  \
# 0                       21.812170                       21.551501  ...
# 1                       19.441001                       19.554205  ...
# 2                       21.573177                       21.589819  ...
#
#    log -4, Прибыль (убыток) от продажи, RUB  \
# 0                                 21.911218
# 1                                 16.606715
# 2                                 19.843448
#
#    log -3, Прибыль (убыток) от продажи, RUB  \
# 0                                 22.547834
# 1                                 16.221710
# 2                                 18.897734
#
#    log -2, Прибыль (убыток) от продажи, RUB  \
# 0                                 20.585863
# 1                                 17.754318
# 2                                -18.348000
#
#    log -1, Прибыль (убыток) от продажи, RUB  \
# 0                                 22.020356
# 1                                 18.359977
# 2                                -18.608993
#
#    Нематериальные активы ,прирост за -3 год  \
# 0                                  0.399219
# 1                                  0.398596
# 2                                  0.400549
#
#    Нематериальные активы ,прирост за -2 год  \
# 0                                  0.427066
# 1                                  0.426438
# 2                                  0.425503
#
#    Нематериальные активы ,прирост за -1 год  \
# 0                                  0.259396
# 1                                  0.259114
# 2                                  0.257865
#
#    Основные средства  ,прирост за -3 год  \
# 0                               0.062215
# 1                               0.062574
# 2                               0.062457
#
#    Основные средства  ,прирост за -2 год  \
# 0                               0.121706
# 1                               0.119087
# 2                               0.118934
#
#    Основные средства  ,прирост за -1 год  \
# 0                               0.182397
# 1                               0.176415
# 2                               0.176741
#
#    Внеоборотные активы ,прирост за -3 год  \
# 0                                0.470383
# 1                                0.470465
# 2                                0.470559
#
#    Внеоборотные активы ,прирост за -2 год  \
# 0                                0.107139
# 1                                0.105733
# 2                                0.105678
#
#    Внеоборотные активы ,прирост за -1 год  \
# 0                                0.105002
# 1                                0.101040
# 2                                0.101643
#
#    Дебиторская задолженность ,прирост за -3 год  \
# 0                                      0.426703
# 1                                      0.425169
# 2                                      0.424600
#
#    Дебиторская задолженность ,прирост за -2 год  \
# 0                                      0.285098
# 1                                      0.287731
# 2                                      0.286789
#
#    Дебиторская задолженность ,прирост за -1 год  \
# 0                                      0.451109
# 1                                      0.449978
# 2                                      0.450157
#
#    Оборотные активы ,прирост за -3 год  Оборотные активы ,прирост за -2 год  \
# 0                             0.500768                             0.226446
# 1                             0.495089                             0.226030
# 2                             0.496402                             0.226028
#
#    Оборотные активы ,прирост за -1 год  Уставный капитал  ,прирост за -3 год  \
# 0                             0.653864                              0.366381
# 1                             0.656262                              0.366381
# 2                             0.654563                              0.366381
#
#    Уставный капитал  ,прирост за -2 год  Уставный капитал  ,прирост за -1 год  \
# 0                              0.366381                              0.308731
# 1                              0.366381                              0.308731
# 2                              0.366381                              0.308731
#
#    Капитал и резервы ,прирост за -3 год  Капитал и резервы ,прирост за -2 год  \
# 0                              0.463603                              0.394300
# 1                              0.462495                              0.396880
# 2                              0.463343                              0.396902
#
#    Капитал и резервы ,прирост за -1 год  \
# 0                              0.473339
# 1                              0.467279
# 2                              0.465850
#
#    Заёмные средства (долгосрочные) ,прирост за -3 год  \
# 0                                           0.376589
# 1                                           0.376589
# 2                                           0.376589
#
#    Заёмные средства (долгосрочные) ,прирост за -2 год  \
# 0                                           0.254968
# 1                                           0.254968
# 2                                           0.254968
#
#    Заёмные средства (долгосрочные) ,прирост за -1 год  \
# 0                                           0.341494
# 1                                           0.341494
# 2                                           0.341494
#
#    Долгосрочные обязательства ,прирост за -3 год  \
# 0                                       0.417620
# 1                                       0.417605
# 2                                       0.417599
#
#    Долгосрочные обязательства ,прирост за -2 год  \
# 0                                       0.335138
# 1                                       0.335102
# 2                                       0.335073
#
#    Долгосрочные обязательства ,прирост за -1 год  \
# 0                                       0.568548
# 1                                       0.568539
# 2                                       0.568532
#
#    Заёмные средства (краткосрочные) ,прирост за -3 год  \
# 0                                           0.273432
# 1                                           0.273639
# 2                                           0.273432
#
#    Заёмные средства (краткосрочные) ,прирост за -2 год  \
# 0                                           0.365963
# 1                                           0.364219
# 2                                           0.364145
#
#    Заёмные средства (краткосрочные) ,прирост за -1 год  \
# 0                                           0.454262
# 1                                           0.456821
# 2                                           0.456703
#
#    Кредиторская задолженность ,прирост за -3 год  \
# 0                                       0.478219
# 1                                       0.474562
# 2                                       0.474611
#
#    Кредиторская задолженность ,прирост за -2 год  \
# 0                                       0.447204
# 1                                       0.439270
# 2                                       0.439100
#
#    Кредиторская задолженность ,прирост за -1 год  \
# 0                                       0.266967
# 1                                       0.278712
# 2                                       0.278569
#
#    Краткосрочные обязательства ,прирост за -3 год  \
# 0                                        0.301946
# 1                                        0.300109
# 2                                        0.300103
#
#    Краткосрочные обязательства ,прирост за -2 год  \
# 0                                        0.359022
# 1                                        0.353359
# 2                                        0.353280
#
#    Краткосрочные обязательства ,прирост за -1 год  Выручка ,прирост за -3 год  \
# 0                                        0.361127                    0.536738
# 1                                        0.370455                    0.445104
# 2                                        0.370278                    0.444558
#
#    Выручка ,прирост за -2 год  Выручка ,прирост за -1 год  \
# 0                    0.081254                    0.265804
# 1                    0.104861                    0.286121
# 2                    0.102957                    0.286042
#
#    Себестоимость продаж ,прирост за -3 год  \
# 0                                 0.576966
# 1                                 0.394586
# 2                                 0.396762
#
#    Себестоимость продаж ,прирост за -2 год  \
# 0                                 0.345443
# 1                                 0.332787
# 2                                 0.331652
#
#    Себестоимость продаж ,прирост за -1 год  \
# 0                                 0.361555
# 1                                 0.407451
# 2                                 0.407604
#
#    Прибыль (убыток) до налогообложения  ,прирост за -3 год  \
# 0                                           0.781340
# 1                                           0.766791
# 2                                           0.766144
#
#    Прибыль (убыток) до налогообложения  ,прирост за -2 год  \
# 0                                           0.223919
# 1                                           0.239787
# 2                                           0.238867
#
#    Прибыль (убыток) до налогообложения  ,прирост за -1 год  \
# 0                                           0.544796
# 1                                           0.540806
# 2                                           0.539709
#
#    Прибыль (убыток) от продажи ,прирост за -3 год  \
# 0                                        0.459739
# 1                                        0.430115
# 2                                        0.427598
#
#    Прибыль (убыток) от продажи ,прирост за -2 год  \
# 0                                        0.117739
# 1                                        0.150148
# 2                                        0.148371
#
#    Прибыль (убыток) от продажи ,прирост за -1 год  \
# 0                                        0.287366
# 1                                        0.272340
# 2                                        0.271954
#
#    Нематериальные активы, относительный прирост за -3 год  \
# 0                                           0.566144
# 1                                          -0.131451
# 2                                           1.154642
#
#    Нематериальные активы, относительный прирост за -2 год  \
# 0                                           0.369172
# 1                                          -0.131451
# 2                                           0.133329
#
#    Нематериальные активы, относительный прирост за -1 год  \
# 0                                           0.342525
# 1                                          -0.137017
# 2                                           0.286086
#
#    Основные средства , относительный прирост за -3 год  \
# 0                                           0.274936
# 1                                           0.061909
# 2                                           0.021189
#
#    Основные средства , относительный прирост за -2 год  \
# 0                                           0.381751
# 1                                           0.073558
# 2                                           0.036979
#
#    Основные средства , относительный прирост за -1 год  \
# 0                                           0.445889
# 1                                           0.089274
# 2                                           0.054838
#
#    Внеоборотные активы, относительный прирост за -3 год  \
# 0                                           0.268095
# 1                                           0.062662
# 2                                           0.086186
#
#    Внеоборотные активы, относительный прирост за -2 год  \
# 0                                           0.365729
# 1                                           0.074121
# 2                                           0.093291
#
#    Внеоборотные активы, относительный прирост за -1 год  \
# 0                                           0.388528
# 1                                           0.089719
# 2                                           0.130090
#
#    Дебиторская задолженность, относительный прирост за -3 год  \
# 0                                           0.011231
# 1                                           0.763914
# 2                                           0.007312
#
#    Дебиторская задолженность, относительный прирост за -2 год  \
# 0                                           0.005712
# 1                                           1.072661
# 2                                           0.068205
#
#    Дебиторская задолженность, относительный прирост за -1 год  \
# 0                                           0.026430
# 1                                           0.649536
# 2                                           0.096767
#
#    Оборотные активы, относительный прирост за -3 год  \
# 0                                          -0.002236
# 1                                           0.364231
# 2                                          -0.082722
#
#    Оборотные активы, относительный прирост за -2 год  \
# 0                                          -0.050659
# 1                                           0.393903
# 2                                          -0.162660
#
#    Оборотные активы, относительный прирост за -1 год  \
# 0                                          -0.077726
# 1                                           0.346925
# 2                                          -0.239519
#
#    Уставный капитал , относительный прирост за -3 год  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    Уставный капитал , относительный прирост за -2 год  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    Уставный капитал , относительный прирост за -1 год  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    Капитал и резервы, относительный прирост за -3 год  \
# 0                                           0.335721
# 1                                           0.117955
# 2                                          -0.031654
#
#    Капитал и резервы, относительный прирост за -2 год  \
# 0                                           0.410466
# 1                                           0.151474
# 2                                          -0.078377
#
#    Капитал и резервы, относительный прирост за -1 год  \
# 0                                           0.623777
# 1                                           0.162012
# 2                                          -0.110097
#
#    Заёмные средства (долгосрочные), относительный прирост за -3 год  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    Заёмные средства (долгосрочные), относительный прирост за -2 год  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    Заёмные средства (долгосрочные), относительный прирост за -1 год  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    Долгосрочные обязательства, относительный прирост за -3 год  \
# 0                                           0.034365
# 1                                           0.230903
# 2                                          -0.625524
#
#    Долгосрочные обязательства, относительный прирост за -2 год  \
# 0                                           0.033687
# 1                                           0.155616
# 2                                          -0.795049
#
#    Долгосрочные обязательства, относительный прирост за -1 год  \
# 0                                           0.029152
# 1                                           0.170259
# 2                                          -0.806858
#
#    Заёмные средства (краткосрочные), относительный прирост за -3 год  \
# 0                                          -1.000000
# 1                                           1.505493
# 2                                           0.000000
#
#    Заёмные средства (краткосрочные), относительный прирост за -2 год  \
# 0                                          -1.000000
# 1                                           0.712292
# 2                                           0.000000
#
#    Заёмные средства (краткосрочные), относительный прирост за -1 год  \
# 0                                          -1.000000
# 1                                           0.838446
# 2                                           0.000000
#
#    Кредиторская задолженность, относительный прирост за -3 год  \
# 0                                          -0.014482
# 1                                           1.958509
# 2                                           0.134278
#
#    Кредиторская задолженность, относительный прирост за -2 год  \
# 0                                          -0.049772
# 1                                           2.571691
# 2                                           0.154368
#
#    Кредиторская задолженность, относительный прирост за -1 год  \
# 0                                          -0.143015
# 1                                           1.590372
# 2                                           0.073355
#
#    Краткосрочные обязательства, относительный прирост за -3 год  \
# 0                                           0.000778
# 1                                           1.194184
# 2                                           0.178137
#
#    Краткосрочные обязательства, относительный прирост за -2 год  \
# 0                                          -0.029615
# 1                                           0.902554
# 2                                           0.144985
#
#    Краткосрочные обязательства, относительный прирост за -1 год  \
# 0                                          -0.142741
# 1                                           0.788463
# 2                                           0.091658
#
#    Выручка, относительный прирост за -3 год  \
# 0                                  0.107843
# 1                                  0.483786
# 2                                 -0.002836
#
#    Выручка, относительный прирост за -2 год  \
# 0                                 -0.043012
# 1                                  0.642599
# 2                                  0.006647
#
#    Выручка, относительный прирост за -1 год  \
# 0                                 -0.020614
# 1                                  0.486298
# 2                                  0.022073
#
#    Себестоимость продаж, относительный прирост за -3 год  \
# 0                                           0.118288
# 1                                           0.437026
# 2                                           0.064829
#
#    Себестоимость продаж, относительный прирост за -2 год  \
# 0                                          -0.024438
# 1                                           0.582943
# 2                                           0.063456
#
#    Себестоимость продаж, относительный прирост за -1 год  \
# 0                                          -0.042865
# 1                                           0.434332
# 2                                           0.063474
#
#    Прибыль (убыток) до налогообложения , относительный прирост за -3 год  \
# 0                                           1.296771
# 1                                           1.992173
# 2                                          -3.196356
#
#    Прибыль (убыток) до налогообложения , относительный прирост за -2 год  \
# 0                                           1.415793
# 1                                           2.798625
# 2                                          -4.170135
#
#    Прибыль (убыток) до налогообложения , относительный прирост за -1 год  \
# 0                                           2.180730
# 1                                           1.914447
# 2                                          -5.305080
#
#    Прибыль (убыток) от продажи, относительный прирост за -3 год  \
# 0                                           1.076057
# 1                                           1.381049
# 2                                          -0.630161
#
#    Прибыль (убыток) от продажи, относительный прирост за -2 год  \
# 0                                           1.138051
# 1                                           1.947916
# 2                                          -0.636349
#
#    Прибыль (убыток) от продажи, относительный прирост за -1 год
# 0                                           1.803874
# 1                                           1.387141
# 2                                          -0.322764
#
# [3 rows x 233 columns]

# %%
best = hyperopt_for_catboost(df)
# Out:
#
# CatBoost objective call #1 cur_best_score=0.00000
# Params: class_w=0.05491598709378827 learning_rate=0.0738512408548754
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64E50> with treshold = 0.5...
# nb_trees=500
# NEW BEST LOSS=15.62242487928982
# NEW BEST ROC_AUC=0.5900058937442115
#
# CatBoost objective call #2 cur_best_score=0.59001
# Params: class_w=0.047318695328767216 learning_rate=0.003822671837168576
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64CA0> with treshold = 0.5...
# nb_trees=500
# NEW BEST LOSS=12.96540648275169
# NEW BEST ROC_AUC=0.6651090342679128
#
# CatBoost objective call #3 cur_best_score=0.66511
# Params: class_w=0.037327402028966505 learning_rate=0.0037485899328259
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64CA0> with treshold = 0.5...
# nb_trees=500
# NEW BEST LOSS=12.752845404676606
# NEW BEST ROC_AUC=0.6752125957733435
#
# CatBoost objective call #4 cur_best_score=0.67521
# Params: class_w=0.0018701908198182435 learning_rate=0.14472721130096752
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64D00> with treshold = 0.5...
# nb_trees=500
# NEW BEST LOSS=11.477513380423092
# NEW BEST ROC_AUC=0.7110802391176223
#
# CatBoost objective call #5 cur_best_score=0.71108
# Params: class_w=0.08623321596958061 learning_rate=0.003074591290008139
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64D00> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #6 cur_best_score=0.71108
# Params: class_w=0.0053511593766292324 learning_rate=0.14817610222521257
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64D00> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #7 cur_best_score=0.71108
# Params: class_w=0.08455798146216235 learning_rate=0.01925964813696988
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FA00> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #8 cur_best_score=0.71108
# Params: class_w=0.014380267043010781 learning_rate=0.2229590925475331
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64D00> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #9 cur_best_score=0.71108
# Params: class_w=0.013543699342556744 learning_rate=0.13772001130470435
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64CA0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #10 cur_best_score=0.71108
# Params: class_w=0.012660636626353623 learning_rate=0.09047218790466427
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64CA0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #11 cur_best_score=0.71108
# Params: class_w=0.009551901979788736 learning_rate=0.0053613521327445955
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FCD0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #12 cur_best_score=0.71108
# Params: class_w=0.0768423762584832 learning_rate=0.1766828467337412
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64CA0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #13 cur_best_score=0.71108
# Params: class_w=0.02933831266857541 learning_rate=0.02523952672683231
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04F8E0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #14 cur_best_score=0.71108
# Params: class_w=0.052314835204663825 learning_rate=0.3086617916997705
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64CA0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #15 cur_best_score=0.71108
# Params: class_w=0.055333864917332144 learning_rate=0.02687066022212333
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64D00> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #16 cur_best_score=0.71108
# Params: class_w=0.036806673057693196 learning_rate=0.0027480691682358143
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64D00> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #17 cur_best_score=0.71108
# Params: class_w=0.06324684924629671 learning_rate=0.1412408593827495
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64D00> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #18 cur_best_score=0.71108
# Params: class_w=0.04860230354909276 learning_rate=0.011530282182431984
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64D00> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #19 cur_best_score=0.71108
# Params: class_w=0.055334498651146584 learning_rate=0.011349729378614686
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64CA0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #20 cur_best_score=0.71108
# Params: class_w=0.05896685661453972 learning_rate=0.029830337920021974
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04F8E0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #21 cur_best_score=0.71108
# Params: class_w=0.02552027201974528 learning_rate=0.05632971177235961
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64D00> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #22 cur_best_score=0.71108
# Params: class_w=0.09971781003934642 learning_rate=0.05394481402752539
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64D00> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #23 cur_best_score=0.71108
# Params: class_w=0.0010175942708726474 learning_rate=0.32337411839253555
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04F400> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #24 cur_best_score=0.71108
# Params: class_w=0.025670146484667415 learning_rate=0.010659608033855137
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBEF64D00> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #25 cur_best_score=0.71108
# Params: class_w=0.03493992426870792 learning_rate=0.005340326433442648
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04F3A0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #26 cur_best_score=0.71108
# Params: class_w=0.04165149157591709 learning_rate=0.053495048395794054
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FCA0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #27 cur_best_score=0.71108
# Params: class_w=0.06973903719831863 learning_rate=0.09805922091183086
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04F730> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #28 cur_best_score=0.71108
# Params: class_w=0.02185280926515297 learning_rate=0.006978094000752928
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04F460> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #29 cur_best_score=0.71108
# Params: class_w=0.00339728404764459 learning_rate=0.04125390691504072
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04F760> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #30 cur_best_score=0.71108
# Params: class_w=0.005146666110921174 learning_rate=0.04193262250689036
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FAC0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #31 cur_best_score=0.71108
# Params: class_w=0.020086547740468787 learning_rate=0.07561517375512594
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04F760> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #32 cur_best_score=0.71108
# Params: class_w=0.006916741820369256 learning_rate=0.016344174825895404
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04F400> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #33 cur_best_score=0.71108
# Params: class_w=0.0015634112345241742 learning_rate=0.038057466573263414
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #34 cur_best_score=0.71108
# Params: class_w=0.01737531427911585 learning_rate=0.19273868286586654
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FAC0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #35 cur_best_score=0.71108
# Params: class_w=0.03083088298404419 learning_rate=0.10988045383700365
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #36 cur_best_score=0.71108
# Params: class_w=0.09424712480423232 learning_rate=0.25949020860615984
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #37 cur_best_score=0.71108
# Params: class_w=0.0008265214773944701 learning_rate=0.07070917833274379
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FAC0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #38 cur_best_score=0.71108
# Params: class_w=0.009881247031074071 learning_rate=0.1197407510898452
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B1C0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #39 cur_best_score=0.71108
# Params: class_w=0.017388445746764833 learning_rate=0.0194565123615665
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #40 cur_best_score=0.71108
# Params: class_w=0.006617858193487015 learning_rate=0.03747998089391128
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #41 cur_best_score=0.71108
# Params: class_w=0.0440714075539256 learning_rate=0.07996545114921531
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B1F0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #42 cur_best_score=0.71108
# Params: class_w=0.08499414795358265 learning_rate=0.18320853812470567
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #43 cur_best_score=0.71108
# Params: class_w=0.07812893670360603 learning_rate=0.22865495242385134
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07BC10> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #44 cur_best_score=0.71108
# Params: class_w=0.011370186396210204 learning_rate=0.018666222806778987
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #45 cur_best_score=0.71108
# Params: class_w=0.029274750516253535 learning_rate=0.35519690941731247
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #46 cur_best_score=0.71108
# Params: class_w=0.04102898492512651 learning_rate=0.06368162447288163
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07BD30> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #47 cur_best_score=0.71108
# Params: class_w=0.015584190025426535 learning_rate=0.04661220786514833
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B550> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #48 cur_best_score=0.71108
# Params: class_w=0.06578376823555765 learning_rate=0.023226975657816562
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B250> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #49 cur_best_score=0.71108
# Params: class_w=0.02450035761097231 learning_rate=0.1547149666237884
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #50 cur_best_score=0.71108
# Params: class_w=0.035257289764857154 learning_rate=0.03226401873818499
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B940> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #51 cur_best_score=0.71108
# Params: class_w=0.007307769804459085 learning_rate=0.2721753966403191
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07BDF0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #52 cur_best_score=0.71108
# Params: class_w=0.04521315272045091 learning_rate=0.013399256571094236
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #53 cur_best_score=0.71108
# Params: class_w=0.013357338636351133 learning_rate=0.008317315322567683
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B970> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #54 cur_best_score=0.71108
# Params: class_w=0.09187320397203805 learning_rate=0.08921615872089858
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B910> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #55 cur_best_score=0.71108
# Params: class_w=0.029959441632107085 learning_rate=0.13467999616613738
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07BDC0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #56 cur_best_score=0.71108
# Params: class_w=0.051433576722079835 learning_rate=0.03234989668437381
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07BD00> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #57 cur_best_score=0.71108
# Params: class_w=0.07355292681084276 learning_rate=0.0031932821267355123
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07BFD0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #58 cur_best_score=0.71108
# Params: class_w=0.02146552194410862 learning_rate=0.045759438141638915
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B430> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #59 cur_best_score=0.71108
# Params: class_w=0.06105896562635685 learning_rate=0.004526589045538627
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04F340> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #60 cur_best_score=0.71108
# Params: class_w=0.002936123847085853 learning_rate=0.10722164631320492
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B640> with treshold = 0.5...
# nb_trees=500
# NEW BEST LOSS=11.158713588406814
# NEW BEST ROC_AUC=0.7151216637197946
#
# CatBoost objective call #61 cur_best_score=0.71512
# Params: class_w=0.03221917046433469 learning_rate=0.22918188892997993
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF085430> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #62 cur_best_score=0.71512
# Params: class_w=0.08112189609052972 learning_rate=0.15424310574344738
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B820> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #63 cur_best_score=0.71512
# Params: class_w=0.025989892308305278 learning_rate=0.1028586326701579
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07BE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #64 cur_best_score=0.71512
# Params: class_w=0.03914260749664569 learning_rate=0.30150217979743366
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B430> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #65 cur_best_score=0.71512
# Params: class_w=0.004364503533032304 learning_rate=0.12785439675445656
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04F340> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #66 cur_best_score=0.71512
# Params: class_w=0.0009188142493662074 learning_rate=0.0636332958639262
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B1F0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #67 cur_best_score=0.71512
# Params: class_w=0.010035554438809415 learning_rate=0.02596949234637836
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07BDC0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #68 cur_best_score=0.71512
# Params: class_w=0.01861008252764952 learning_rate=0.08456281762999343
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B700> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #69 cur_best_score=0.71512
# Params: class_w=0.0038817623187970282 learning_rate=0.1121604018366165
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B130> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #70 cur_best_score=0.71512
# Params: class_w=0.013643285335883137 learning_rate=0.19177510443043402
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B400> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #71 cur_best_score=0.71512
# Params: class_w=0.0033661920073905383 learning_rate=0.16855785669466974
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B400> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #72 cur_best_score=0.71512
# Params: class_w=0.02400600381232436 learning_rate=0.062102471953106614
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B550> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #73 cur_best_score=0.71512
# Params: class_w=0.008561206857562651 learning_rate=0.11138487540802693
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B130> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #74 cur_best_score=0.71512
# Params: class_w=0.010963768593460673 learning_rate=0.2625197167833793
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B130> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #75 cur_best_score=0.71512
# Params: class_w=0.00029352720839318034 learning_rate=0.21070763815219581
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B130> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #76 cur_best_score=0.71512
# Params: class_w=0.016987068336895575 learning_rate=0.09477980833611514
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #77 cur_best_score=0.71512
# Params: class_w=0.005064400170567603 learning_rate=0.36020945474696475
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #78 cur_best_score=0.71512
# Params: class_w=0.020919224585180998 learning_rate=0.052326098323839915
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF085D90> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #79 cur_best_score=0.71512
# Params: class_w=0.014826796943703414 learning_rate=0.07498491637206026
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #80 cur_best_score=0.71512
# Params: class_w=0.032966751799157056 learning_rate=0.12056012333129773
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B130> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #81 cur_best_score=0.71512
# Params: class_w=0.04701404422120294 learning_rate=0.16622689216216696
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B130> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #82 cur_best_score=0.71512
# Params: class_w=0.02764456136678513 learning_rate=0.14061314755065718
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF085280> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #83 cur_best_score=0.71512
# Params: class_w=0.05496564531358756 learning_rate=0.02255765804666268
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF085610> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #84 cur_best_score=0.71512
# Params: class_w=0.00854051216188964 learning_rate=0.29657613238736535
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF085E80> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #85 cur_best_score=0.71512
# Params: class_w=0.057869647723952665 learning_rate=0.03542363172713676
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF085400> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #86 cur_best_score=0.71512
# Params: class_w=0.02258592510252134 learning_rate=0.20702313985966064
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF085160> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #87 cur_best_score=0.71512
# Params: class_w=0.0025365907497699606 learning_rate=0.2430183891986285
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B130> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #88 cur_best_score=0.71512
# Params: class_w=0.0027389999584281986 learning_rate=0.23838877335873254
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B130> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #89 cur_best_score=0.71512
# Params: class_w=0.019092135853242143 learning_rate=0.3608178713477286
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B130> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #90 cur_best_score=0.71512
# Params: class_w=0.006487895321820801 learning_rate=0.07006981751128069
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF085460> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #91 cur_best_score=0.71512
# Params: class_w=0.011995802605420231 learning_rate=0.046584378422286125
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF0853A0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #92 cur_best_score=0.71512
# Params: class_w=0.03703550097595154 learning_rate=0.08056767071764923
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF085250> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #93 cur_best_score=0.71512
# Params: class_w=0.0656007338394156 learning_rate=0.10690158477613527
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF07B130> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #94 cur_best_score=0.71512
# Params: class_w=0.015895770420115283 learning_rate=0.028763871388792335
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF04FE20> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #95 cur_best_score=0.71512
# Params: class_w=0.028242365851516172 learning_rate=0.3301729057520245
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF0852E0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #96 cur_best_score=0.71512
# Params: class_w=0.08957545163916106 learning_rate=0.013397987384888208
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF085910> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #97 cur_best_score=0.71512
# Params: class_w=0.09665784112492656 learning_rate=0.24457777011847875
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF085D90> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #98 cur_best_score=0.71512
# Params: class_w=0.002343694355366803 learning_rate=0.15301764508601085
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF085CD0> with treshold = 0.5...
# nb_trees=500
# NEW BEST LOSS=10.839886733092897
# NEW BEST ROC_AUC=0.704891807695546
#
# CatBoost objective call #99 cur_best_score=0.70489
# Params: class_w=0.041619591881895644 learning_rate=0.15122416526067986
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF0850A0> with treshold = 0.5...
# nb_trees=500
#
# CatBoost objective call #100 cur_best_score=0.70489
# Params: class_w=0.0008072017412693385 learning_rate=0.2795031345082313
# Fitting model <catboost.core.CatBoostClassifier object at 0x0000023FBF085A60> with treshold = 0.5...
# nb_trees=500
# 100%|██████████████████████████████████████████████| 100/100 [10:35<00:00,  6.35s/trial, best loss: 10.839886733092897]
# --------------------------------------------------
# The best params:
# {'class_w': 0.002343694355366803, 'learning_rate': 0.15301764508601085}
