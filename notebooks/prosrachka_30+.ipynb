# %%
from functools import partial

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', 400)
pd.set_option('display.max_rows', 100)

from server2022.data.processed.prepare_data import create_df_2years_known, create_df_0years_known, create_df_1year_known
from server2022.data.processed.prepare_data import factors_2020, FINANCE_FEAT, FIN_FEATS_TO_LEAVE

# %%
df_2020 = pd.read_csv('../server2022/data/raw/agents2020.csv')

# %%
def drop_unneeded_companies_and_features(df):
    df_res = df.copy()
    feats_to_live = list(set(FIN_FEATS_TO_LEAVE) & set(df_res.columns.tolist()))
    df_res = df_res[(df_res[feats_to_live].abs() > 10).all()]
    cols_to_drop = list(set(financial_report_columns) - set(feats_to_live))
    df_res.drop(columns=cols_to_drop, inplace=True)
    return df_res

# %%
df_res = df_2020.copy()
feats_to_live = list(set(FIN_FEATS_TO_LEAVE) & set(df_res.columns.tolist()))
# df_res = df_res[(df_res[feats_to_live].abs() > 10).all()]
# cols_to_drop = list(set(financial_report_columns) - set(feats_to_live))
# df_res.drop(columns=cols_to_drop, inplace=True)

# %%
(df_res[feats_to_live].abs() > 10).all(axis=1)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 526     True
# 527     True
# 528    False
# 529     True
# 530    False
# Length: 531, dtype: bool

# %%
df_1 = create_df_1year_known()
# Out:
# /home/zakharov_a/new_miniconda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/zakharov_a/new_miniconda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/zakharov_a/new_miniconda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/zakharov_a/new_miniconda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/zakharov_a/new_miniconda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
df_1.head()
# Out:
#    Наименование ДП Факт. 1 Факт. 2 Факт. 3 Факт. 7 Факт. 12 Факт. 14 Факт. 15  \
# 0                0       Х       Х       Х       Х        Х        Х        Х
# 1                1       Х       Х       Х       Х        Х        Х        Х
# 2                2       Х       Х       Х       Х        Х        Х        Х
# 3                3       Х       Х       Х       Х        Х        Х        Х
# 4                4       Х       Х       Х       Х        Х        Х        Х
#
#   Факт. 16 Факт. 20 Факт. 21 Факт. 23 Факт. 24 Факт. 27 Факт. 28 Факт. 29  \
# 0        Х        Х        Х        Х        Х        Х        Х        Х
# 1        Х        Х        Х        Х        Х        Х        Х        Х
# 2        Х        Х        Х        Х        Х        Х        Х       30
# 3        Х        Х        Х        Х        Х        Х        Х        Х
# 4        Х        Х        Х        Х        Х        Х        Х        Х
#
# ...

# %%
df_1.shape
# Out:
# (745, 87)

# %%
(df_1['year'] == '2021').sum()
# Out:
# 278

# %%
(df_1['year'] == '2020').sum()
# Out:
# 467

# %%
companies2021 = df_1[df_1['year'] == '2021']['Наименование ДП'].values

# %%
df_1[(df_1['year'] == '2020') & (df_1['Наименование ДП'].isin(companies2021))]['target_more30days'].sum()
# Out:
# 54

# %%
df_1[(df_1['year'] == '2020') & (df_1['Наименование ДП'].isin(companies2021))]['target_more90days'].sum()
# Out:
# 25

# %%
df_1[(df_1['year'] == '2021') & (df_1['Наименование ДП'].isin(companies2021))]['target_more30days'].sum()
# Out:
# 77

# %%
df_1[(df_1['year'] == '2021') & (df_1['Наименование ДП'].isin(companies2021))]['target_more90days'].sum()
# Out:
# 67

# %%
df_0 = create_df_0years_known()
# Out:
# /home/zakharov_a/new_miniconda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/zakharov_a/new_miniconda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/zakharov_a/new_miniconda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/zakharov_a/new_miniconda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/zakharov_a/new_miniconda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
df_0.head()
# Out:
#    Наименование ДП  year  binary_target  target_more30days  target_more90days  \
# 0                0  2019          False              False              False
# 1                1  2019          False              False              False
# 2                2  2019           True              False              False
# 3                3  2019          False              False              False
# 4                4  2019           True              False              False
#
#    Итого  -1, Основные средства , RUB  -1, Внеоборотные активы, RUB  \
# 0    NaN                 2.145239e+09                  2.440078e+09
# 1    NaN                 1.526427e+08                  1.538924e+08
# 2    NaN                 9.287389e+08                  1.018682e+09
# 3    NaN                 1.426492e+10                  1.820102e+10
# 4    NaN                 3.008970e+10                  1.001542e+11
#
#    -1, Дебиторская задолженность, RUB  -1, Оборотные активы, RUB  \
# ...

# %%
(df_0['year'] == '2021').sum()
# Out:
# 278

# %%
companies2021 = df_0[df_0['year'] == '2021']['Наименование ДП'].values

# %%
df_0[(df_0['year'] == '2019') & (df_0['Наименование ДП'].isin(companies2021))]['target_more30days'].sum()
# Out:
# 43

# %%
df_0[(df_0['year'] == '2019') & (df_0['Наименование ДП'].isin(companies2021))]['target_more90days'].sum()
# Out:
# 17

# %%
df_0[(df_0['year'] == '2020') & (df_0['Наименование ДП'].isin(companies2021))]['target_more30days'].sum()
# Out:
# 47

# %%
df_0[(df_0['year'] == '2020') & (df_0['Наименование ДП'].isin(companies2021))]['target_more90days'].sum()
# Out:
# 20

# %%
df_0[(df_0['year'] == '2021') & (df_0['Наименование ДП'].isin(companies2021))]['target_more30days'].sum()
# Out:
# 65

# %%
df_0[(df_0['year'] == '2021') & (df_0['Наименование ДП'].isin(companies2021))]['target_more90days'].sum()
# Out:
# 57

# %%
companies2021 = df_0[df_0['year'] == '2021']['Наименование ДП'].values

# %%
df_0[(df_0['year'] == '2019') & (df_0['Наименование ДП'].isin(companies2021))]['target_more30days'].sum()
# Out:
# 46

# %%
df_0[(df_0['year'] == '2019') & (df_0['Наименование ДП'].isin(companies2021))]['target_more90days'].sum()
# Out:
# 20

# %%
df_0[(df_0['year'] == '2020') & (df_0['Наименование ДП'].isin(companies2021))]['target_more30days'].sum()
# Out:
# 54

# %%
df_0[(df_0['year'] == '2020') & (df_0['Наименование ДП'].isin(companies2021))]['target_more90days'].sum()
# Out:
# 25

# %%
df_0[(df_0['year'] == '2021') & (df_0['Наименование ДП'].isin(companies2021))]['target_more30days'].sum()
# Out:
# 77

# %%
df_0[(df_0['year'] == '2021') & (df_0['Наименование ДП'].isin(companies2021))]['target_more90days'].sum()
# Out:
# 67

# %%
df_0[(df_0['year'] == '2021')].shape
# Out:
# (325, 150)

# %%
df_1[df_1['year'] == '2020'][['Наименование ДП', 'binary_target', 'target_more30days']]
# Out:
#      Наименование ДП  binary_target  target_more30days
# 0                  0           True              False
# 1                  1           True              False
# 2                  2           True              False
# 3                  3           True              False
# 4                  4           True              False
# ..               ...            ...                ...
# 526              526          False              False
# 527              527          False              False
# 528              528          False              False
# 529              529          False              False
# 530              530          False              False
#
# [531 rows x 3 columns]

# %%
df_1[(df_1['year'] == '2020') & (df_1['Наименование ДП'].isin(companies2021))]['target_more30days'].sum()
# Out:
# 54

# %%
df_1[(df_1['year'] == '2020') & (df_1['Наименование ДП'].isin(companies2021))][[
    'Наименование ДП', 'target_more30days', 'binary_target']].head(50)
# Out:
#     Наименование ДП  target_more30days  binary_target
# 0                 0              False           True
# 2                 2              False           True
# 4                 4              False           True
# 5                 5              False           True
# 6                 6              False          False
# 7                 7              False           True
# 8                 8              False           True
# 9                 9               True           True
# 12               12              False           True
# 13               13              False           True
# 14               14              False          False
# 17               17              False          False
# 19               19              False          False
# 20               20              False           True
# 21               21              False           True
# 23               23              False           True
# ...

# %%
df_1[(df_1['year'] == '2021') & (df_1['Наименование ДП'].isin(companies2021))]['target_more30days'].sum()
# Out:
# 77

# %%
df_2021 = pd.read_csv('../server2022/data/raw/agents2021.csv')

# %%
df_2020 = pd.read_csv('../server2022/data/raw/agents2020.csv')

# %%
df_2021.head()
# Out:
#    Unnamed: 0  Наименование ДП  Макс. ПДЗ за 2019 год, дней  \
# 0           0                0                            0
# 1           1                2                            7
# 2           2                4                            2
# 3           3                5                            0
# 4           4                6                            0
#
#    Сред. ПДЗ за 2019 год, дней  \
# 0                          0.0
# 1                          5.5
# 2                          2.0
# 3                          0.0
# 4                          0.0
#
#    Кол-во просрочек свыше 5-ти дней за 2019 год, шт.  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Общая сумма ПДЗ свыше 5-ти дней за 2019 год, руб.  \
# ...

# %%
(df_2021[['ПДЗ 31-90', 'ПДЗ 91-365', 'ПДЗ более 365']].sum(axis=1) > 0).sum()
# Out:
# 77

# %%
(df_2020['Макс. ПДЗ за 2020 год, дней'] > 30).sum()
# Out:
# 83

# %%
df_2020.head()
# Out:
#    Наименование ДП Факт. 1 Факт. 2 Факт. 3 Факт. 4 Факт. 5 Факт. 6 Факт. 7  \
# 0                0       Х       Х       Х       Х       Х       Х       Х
# 1                1       Х       Х       Х       Х       Х       Х       Х
# 2                2       Х       Х       Х       Х       Х       Х       Х
# 3                3       Х       Х       Х       Х       Х       Х       Х
# 4                4       Х       Х       Х       Х       Х       Х       Х
#
#   Факт. 8 Факт. 9 Факт. 10 Факт. 11 Факт. 12 Факт. 13 Факт. 14 Факт. 15  \
# 0       Х       Х        Х        Х        Х        Х        Х        Х
# 1       Х       Х        Х        Х        Х        Х        Х        Х
# 2       Х       Х        Х        Х        Х        Х        Х        Х
# 3       Х       Х        Х        Х        Х        Х        Х        Х
# 4       Х       Х        Х        Х        Х        Х        Х        Х
#
#   Факт. 16 Факт. 17 Факт. 18 Факт. 19 Факт. 20 Факт. 21 Факт. 22 Факт. 23  \
# ...
